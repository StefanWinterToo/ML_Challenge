# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
test_file  = np.load("Datasets/test_images_task2.npy")

# %%
#10000 photos, with height (28) and width (200) 
print(test_file.shape)

#take first photo, get height (28) and width (200)
print(test_file[0].shape)

#the vector size (height*width) is 5600 per photo 
print(test_file[0].size)
# Out:
# (10000, 28, 200)
# (28, 200)
# 5600

# %%
#array representation of first photo
#size 5600 values
print("first photo: \n",test_file[0])

#first row of 200 horizontal values 
print("first photo, first row with 200 horizontal values: \n",test_file[0,0])

#take 7th value
print("first photo, first row, seventh value: \n",test_file[0,0,7])
# Out:
# first photo:
#  [[200. 200. 200. ... 200. 200. 200.]
#  [200. 200. 200. ... 200. 210. 211.]
#  [200.  72. 200. ... 200.  75. 200.]
#  ...
#  [231. 200. 229. ... 200. 200. 200.]
#  [194. 200. 175. ... 200. 200. 200.]
#  [200. 200. 200. ...  97. 200. 200.]]
# first photo, first row with 200 horizontal values:
#  [200. 200. 200. 200. 200. 200. 200. 250. 200. 200. 200. 200. 109. 117.
#  200. 200. 143. 200. 200. 140. 200. 223. 200. 200. 200. 200. 203. 200.
#  200.  32. 200. 164. 200. 200. 200. 200. 200. 200. 200. 200.   9. 200.
#  200. 200. 200. 155. 119. 200. 200. 200. 200. 219. 222. 225. 225. 227.
#  228. 229. 229. 230. 230. 232. 231. 230. 231. 233. 234. 230. 231. 231.
#  231. 232. 232. 233. 232. 232. 231. 230. 229. 200. 200. 200. 200. 200.
#   18. 200. 200. 145. 146. 146. 147. 147. 147. 147. 146. 146. 144. 144.
#  142. 141. 140. 140. 139. 139. 135. 134. 133. 133. 131. 130. 129. 125.
#  123. 122. 121. 200. 129.  36. 200. 200. 200. 200. 192. 157. 202. 200.
# ...

# %%
plt.imshow(test_file[0])
